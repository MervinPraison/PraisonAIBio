# %% [markdown]
# # SBML reaction graph
#
# Visualise topology for BIOMD0000000206.

# %%
import praisonai_bio
from praisonai_bio.tools.sbml_to_graph import sbml_to_graph
from praisonai_bio.tools.sbml_summarise import sbml_summarise

print(sbml_summarise.run(model_id="BIOMD0000000206"))
print(sbml_to_graph.run(model_id="BIOMD0000000206"))

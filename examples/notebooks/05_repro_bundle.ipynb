# %% [markdown]
# # Repro bundle export

# %%
import praisonai_bio
from praisonai_bio.tools.repro_export import repro_export

print(repro_export.run(model_id="BIOMD0000000206", run_id="notebook-demo", notes="From notebook 05"))

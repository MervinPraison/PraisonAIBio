# %% [markdown]
# # Search and rank BioModels
#
# Curated glycolysis discovery.

# %%
import praisonai_bio
from praisonai_bio.tools.search_models import search_models
from praisonai_bio.tools.rank_models import rank_models

results = search_models.run(query="glycolysis", num_results=5)
print(results)
print(rank_models.run(search_results_json=results))

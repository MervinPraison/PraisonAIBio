# %% [markdown]
# # Simulate glycolysis
#
# Requires optional BASICO: pip install praisonai-bio[simulation]

# %%
import praisonai_bio
from praisonai_bio.tools.simulate_model import simulate_model

print(simulate_model.run(model_id="BIOMD0000000206", duration=50))

# %% [markdown]
# # Perturb and compare simulations

# %%
import praisonai_bio
from praisonai_bio.tools.simulate_perturbation import simulate_perturbation
from praisonai_bio.tools.compare_simulations import compare_simulations

baseline = simulate_perturbation.run(model_id="BIOMD0000000206", parameter="vGAPD", value=1.0, duration=10)
variant = simulate_perturbation.run(model_id="BIOMD0000000206", parameter="vGAPD", value=1.5, duration=10)
print(compare_simulations.run(baseline_json=baseline, perturbation_json=variant))
